# %% [markdown]
# <a href="https://colab.research.google.com/github/leonelsosav/-MachineLearningColabs/blob/main/curso0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = "curso"
print("este es un " + x)
# Out:
# este es un curso
